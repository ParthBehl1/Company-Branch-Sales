# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')  
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('branches.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating Product  Price
# 0   59227.2                 4.761905       2961.36     5.9     NaN    NaN
# 1   20851.2                 4.761905       1042.56     4.5     NaN    NaN
# 2   36734.4                 4.761905       1836.72     6.8     NaN    NaN
# 3  202435.2                 4.761905      10121.76     4.5     NaN    NaN
# 4   29016.0                 4.761905       1450.80     4.4     NaN    NaN

# %%
df.shape
# Out:
# (2007, 19)

# %%
df.columns.values.tolist()
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Unit price',
#  'Quantity',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'Payment',
#  'cogs',
#  'gross margin percentage',
#  'gross income',
#  'Rating',
#  'Product',
#  'Price']

# %%
df.describe(include=None, percentiles=None)
# Out:
#          Unit price     Quantity       Tax 5%          Total           cogs  \
# count   2000.000000  2007.000000   2000.00000    2000.000000    2000.000000
# mean   20041.966800     5.515197   5536.57284  116268.029640  110731.456800
# std     9535.680197     2.924378   4214.12272   88496.577116   84282.454396
# min     3628.800000     1.000000    183.06000    3844.260000    3661.200000
# 25%    11835.000000     3.000000   2132.95500   44792.055000   42659.100000
# 50%    19882.800000     5.000000   4351.68000   91385.280000   87033.600000
# 75%    28056.600000     8.000000   8080.29000  169686.090000  161605.800000
# max    35985.600000    12.000000  17874.00000  375354.000000  357480.000000
#
#        gross margin percentage  gross income      Rating      Price
# count              2000.000000    2000.00000  2000.00000   7.000000
# mean                  4.761905    5536.57284     6.97270  17.561429
# std                   0.000000    4214.12272     1.71815   7.949993
# min                   4.761905     183.06000     4.00000   9.990000
# 25%                   4.761905    2132.95500     5.50000  11.240000
# 50%                   4.761905    4351.68000     7.00000  12.490000
# 75%                   4.761905    8080.29000     8.50000  25.990000
# max                   4.761905   17874.00000    10.00000  25.990000

# %%
df.isnull().sum()
# Out:
# Invoice ID                    7
# Branch                        7
# City                          7
# Customer type                 7
# Gender                        7
# Product line                  7
# Unit price                    7
# Quantity                      0
# Tax 5%                        7
# Total                         7
# Date                          0
# Time                          7
# Payment                       7
# cogs                          7
# gross margin percentage       7
# gross income                  7
# Rating                        7
# Product                    2000
# Price                      2000
# dtype: int64

# %%
df.notna().sum()
# Out:
# Invoice ID                 2000
# Branch                     2000
# City                       2000
# Customer type              2000
# Gender                     2000
# Product line               2000
# Unit price                 2000
# Quantity                   2007
# Tax 5%                     2000
# Total                      2000
# Date                       2007
# Time                       2000
# Payment                    2000
# cogs                       2000
# gross margin percentage    2000
# gross income               2000
# Rating                     2000
# Product                       7
# Price                         7
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2007 entries, 0 to 2006
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               2000 non-null   object
#  1   Branch                   2000 non-null   object
#  2   City                     2000 non-null   object
#  3   Customer type            2000 non-null   object
#  4   Gender                   2000 non-null   object
#  5   Product line             2000 non-null   object
#  6   Unit price               2000 non-null   float64
#  7   Quantity                 2007 non-null   int64
#  8   Tax 5%                   2000 non-null   float64
#  9   Total                    2000 non-null   float64
#  10  Date                     2007 non-null   object
#  11  Time                     2000 non-null   object
#  12  Payment                  2000 non-null   object
#  13  cogs                     2000 non-null   float64
#  14  gross margin percentage  2000 non-null   float64
#  15  gross income             2000 non-null   float64
#  16  Rating                   2000 non-null   float64
#  17  Product                  7 non-null      object
#  18  Price                    7 non-null      float64
# dtypes: float64(8), int64(1), object(10)
# memory usage: 298.0+ KB

# %%
import datetime as dt

# %%
df['Date']= pd.to_datetime(df['Date'])

# %%
df['Date']
# Out:
# 0     2019-02-20
# 1     2019-02-06
# 2     2019-03-09
# 3     2019-01-15
# 4     2019-03-11
#          ...
# 995   2019-01-23
# 996   2019-01-09
# 997   2019-03-29
# 998   2019-02-18
# 999   2019-01-29
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
type(df['Date'])
# Out:
# pandas.core.series.Series

# %%
df['Time']= pd.to_datetime(df['Time'])

# %%
df['Time']
# Out:
# 0     2022-03-02 13:27:00
# 1     2022-03-02 18:07:00
# 2     2022-03-02 17:03:00
# 3     2022-03-02 16:19:00
# 4     2022-03-02 15:30:00
#               ...
# 995   2022-03-02 10:33:00
# 996   2022-03-02 11:40:00
# 997   2022-03-02 19:12:00
# 998   2022-03-02 11:40:00
# 999   2022-03-02 13:46:00
# Name: Time, Length: 1000, dtype: datetime64[ns]

# %%
type(df['Time'])
# Out:
# pandas.core.series.Series

# %%
 df['Day'] = df['Date'].dt.day

# %%
Newday= df['Day']

# %%
Newday
# Out:
# 0      20
# 1       6
# 2       9
# 3      15
# 4      11
#        ..
# 995    23
# 996     9
# 997    29
# 998    18
# 999    29
# Name: Day, Length: 1000, dtype: int64

# %%
 df['Month'] = df['Date'].dt.month

# %%
NewMonth = df['Month']

# %%
NewMonth
# Out:
# 0      2
# 1      2
# 2      3
# 3      1
# 4      3
#       ..
# 995    1
# 996    1
# 997    3
# 998    2
# 999    1
# Name: Month, Length: 1000, dtype: int64

# %%
 df['Year'] = df['Date'].dt.year

# %%
NewYear=  df['Year']

# %%
NewYear
# Out:
# 0      2019
# 1      2019
# 2      2019
# 3      2019
# 4      2019
#        ...
# 995    2019
# 996    2019
# 997    2019
# 998    2019
# 999    2019
# Name: Year, Length: 1000, dtype: int64

# %%
 df['Hour'] = df['Time'].dt.hour

# %%
newhour=  df['Hour']

# %%
newhour
# Out:
# 0      13
# 1      18
# 2      17
# 3      16
# 4      15
#        ..
# 995    10
# 996    11
# 997    19
# 998    11
# 999    13
# Name: Hour, Length: 1000, dtype: int64

# %%
df['Hour'].nunique()
# Out:
# 11

# %%
df['Hour'].unique()
# Out:
# array([13, 18, 17, 16, 15, 10, 12, 19, 14, 11, 20], dtype=int64)

# %%
#Uncomment the code and Run it
categorical_columns = [col for col in df.columns if df[col].dtype == "object" ]
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %%
#Example - Uncomment the Code and Run it
df['Branch'].unique().tolist()
# Out:
# ['B', 'A', 'C']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(df['Branch'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 3

# %%
print("Total Number of unique values in the Quantity Column : {}". format(len(df['Quantity'].unique().tolist())))
# Out:
# Total Number of unique values in the Quantity Column : 10

# %%
df['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
City_grp = df.groupby('City').sum()

# %%
City_grp
# Out:
#                Unnamed: 0  Unit price  Quantity      Tax 5%        Total  \
# City
# Abuja               54946   6652396.8      1820  1820531.52  38231161.92
# Lagos               57630   6705176.4      1859  1820577.78  38232133.38
# Port Harcourt       53628   6684393.6      1831  1895463.54  39804734.34
#
#                      cogs  gross margin percentage  gross income  Rating  \
# City
# Abuja          36410630.4              1580.952381    1820531.52  2263.6
# Lagos          36411555.6              1619.047619    1820577.78  2389.2
# Port Harcourt  37909270.8              1561.904762    1895463.54  2319.9
#
#                 Day  Month    Year  Hour
# City
# Abuja          5068    665  670308  5029
# Lagos          5232    688  686460  4987
# Port Harcourt  4956    640  662232  4894

# %%
df.groupby('City').mean()
# Out:
#                Unnamed: 0    Unit price  Quantity       Tax 5%          Total  \
# City
# Abuja               165.5  20037.339759  5.481928  5483.528675  115154.102169
# Lagos               169.5  19721.107059  5.467647  5354.640529  112447.451118
# Port Harcourt       163.5  20379.248780  5.582317  5778.852256  121355.897378
#
#                         cogs  gross margin percentage  gross income    Rating  \
# City
# Abuja          109670.573494                 4.761905   5483.528675  6.818072
# Lagos          107092.810588                 4.761905   5354.640529  7.027059
# Port Harcourt  115577.045122                 4.761905   5778.852256  7.072866
#
#                      Day     Month    Year       Hour
# City
# Abuja          15.265060  2.003012  2019.0  15.147590
# Lagos          15.388235  2.023529  2019.0  14.667647
# Port Harcourt  15.109756  1.951220  2019.0  14.920732

# %%
#df.groupby('city').max()
df.groupby('gross income')['City'].max()

# %%
#df=df.groupby(['gross income', 'City']).size().sort_values(ascending=False)

# %%
df.groupby(['City'])['gross income'].mean().sort_values(ascending=False)
# Out:
# City
# Port Harcourt    5778.852256
# Abuja            5483.528675
# Lagos            5354.640529
# Name: gross income, dtype: float64

# %%
sns.countplot(x='Quantity', hue='City', data=df).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.countplot(x='Payment', hue='City', data=df).set_title("Payment Method")
# Out:
# Text(0.5, 1.0, 'production record')

# %%
sns.countplot(y='Product line', data=df).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.countplot(y='Product line', hue='Payment', data=df).set_title("Product analysis")
# Out:
# Text(0.5, 1.0, 'Product analysis')

# %%
sns.countplot(x='Payment', hue='Branch', data=df).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.boxplot(x='Branch', y='gross income', data=df).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')
