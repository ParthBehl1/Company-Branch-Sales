# %%
import os
import glob
import pandas as pd
os.chdir(r"/Users/parthbehl/machine learning/data analysis project/sales_analysis")

# %%
extension = 'csv'
joined_files = os.path.join("/Users/parthbehl/machine learning/data analysis project/sales_analysis/.csv")

# %%
# A list of all joined files is returned
joined_list = glob.glob("/Users/parthbehl/machine learning/data analysis project/sales_analysis/*.csv", recursive=False)

# %%
print(joined_list)
# Out:
# ['/Users/parthbehl/machine learning/data analysis project/sales_analysis/branches.csv', '/Users/parthbehl/machine learning/data analysis project/sales_analysis/Abuja_Branch.csv', '/Users/parthbehl/machine learning/data analysis project/sales_analysis/Port_Harcourt_Branch.csv', '/Users/parthbehl/machine learning/data analysis project/sales_analysis/data.csv', '/Users/parthbehl/machine learning/data analysis project/sales_analysis/Lagos_Branch.csv']

# %%
# Finally, the files are joined
df = pd.concat(map(pd.read_csv, joined_list), ignore_index=True)

# %%
df.to_csv('branches.csv', index=False)

# %%
df=pd.read_csv('branches.csv')

# %%
df.head(10)
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
# 5  371-85-5789      B  Abuja        Normal    Male       Health and beauty
# 6  273-16-6619      B  Abuja        Normal    Male      Home and lifestyle
# 7  649-29-6775      B  Abuja        Normal    Male     Fashion accessories
# 8  145-94-9061      B  Abuja        Normal  Female      Food and beverages
# 9  871-79-8483      B  Abuja        Normal    Male     Fashion accessories
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# ...
